# %%
import pandas as pd
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)

# %%
train = pd.read_csv("C:/Users/HP/DATASETS/winequality.csv",sep=";")

# %%
train.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
train.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
train.shape
# Out:
# (4898, 12)

# %%
train.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
wine_corr = train.corr()
wine_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fig = plt.figure(figsize = (9,8))
HM = sns.heatmap(wine_corr,annot = True,cmap = 'Blues' )

# %%
train.shape
# Out:
# (4898, 12)

# %%
label = train.iloc[:,11]
label.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: quality, dtype: int64

# %%
feature = train.drop(["quality"],axis =1)
feature.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test,Y_train,Y_test = train_test_split(feature,label,test_size = 0.2,random_state = 0)

# %%
X_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4685            7.2              0.26         0.32            10.4      0.062
# 4589            5.4              0.29         0.38             1.2      0.029
# 2700            6.5              0.46         0.31             5.0      0.027
# 283             6.7              0.34         0.30            15.6      0.054
# 1014            6.1              0.16         0.27            12.6      0.064
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4685                 23.0                 114.0  0.99660  3.23       0.49
# 4589                 31.0                 132.0  0.98895  3.28       0.36
# 2700                 15.0                  72.0  0.99165  3.26       0.60
# 283                  51.0                 196.0  0.99820  3.19       0.49
# 1014                 63.0                 162.0  0.99940  3.66       0.43
#
#       alcohol
# 4685     10.5
# 4589     12.4
# ...

# %%
X_test.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2762            7.3              0.32         0.35            1.40      0.050
# 42              7.0              0.31         0.26            7.40      0.069
# 1419            7.6              0.14         0.74            1.60      0.040
# 3664            5.0              0.29         0.54            5.70      0.035
# 2125            6.0              0.28         0.22           12.15      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2762                  8.0                 163.0  0.99244  3.24       0.42
# 42                   28.0                 160.0  0.99540  3.13       0.46
# 1419                 27.0                 103.0  0.99160  3.07       0.40
# 3664                 54.0                 155.0  0.98976  3.27       0.34
# 2125                 42.0                 163.0  0.99570  3.20       0.46
#
#       alcohol
# 2762     10.7
# 42        9.8
# ...

# %%
Y_train.head()
# Out:
# 4685    5
# 4589    6
# 2700    7
# 283     5
# 1014    5
# Name: quality, dtype: int64

# %%
Y_test.head()
# Out:
# 2762    5
# 42      6
# 1419    7
# 3664    8
# 2125    5
# Name: quality, dtype: int64

# %%
X_train.shape, Y_train.shape
# Out:
# ((3918, 11), (3918,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((980, 11), (980,))

# %%
import numpy as np
import math
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
model1 = sm.OLS(Y_train,X_train)
result = model1.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                 2.264e+04
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):               0.00
# Time:                        01:01:31   Log-Likelihood:                -4380.5
# No. Observations:                3918   AIC:                             8783.
# Df Residuals:                    3907   BIC:                             8852.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# fixed acidity           -0.0408      0.017     -2.422      0.015      -0.074      -0.008
# ...

# %%
y_predict = regr.predict(X_test)

# %%
y_predict
# Out:
# array([ 5.59064994,  5.46612209,  6.08826801,  6.7935377 ,  5.97054831,
#         4.15423325,  6.53858017,  6.27153883,  5.94339097,  5.79333728,
#         5.75373171,  5.45667801,  5.13997293,  5.52464742,  6.21729591,
#         5.74754765,  6.31477849,  5.50810327,  6.76247337,  6.17944272,
#         5.91597932,  6.22926151,  5.97536336,  5.91117045,  5.8372182 ,
#         6.4279924 ,  4.89423106,  5.19864679,  6.36788167,  5.65392916,
#         5.38257257,  5.79775722,  6.21169274,  6.36035842,  5.38105671,
#         6.14379123,  6.17885898,  5.50015702,  6.21194669,  5.79581071,
#         6.22621364,  5.9667525 ,  5.70667088,  5.61747744,  5.39818495,
#         6.55552855,  5.29839102,  6.52852706,  6.50702693,  5.50656612,
#         6.76096171,  6.22691935,  5.40767427,  5.77843246,  6.00322767,
#         6.37586016,  5.69506027,  6.22814781,  5.15773657,  6.56755237,
#         5.65540713,  5.38660498,  6.2676798 ,  6.14119576,  6.13779365,
# ...

# %%
y_predict = pd.DataFrame(y_predict)       #see the difference after converting it to dataframe
y_predict.head()
# Out:
#           0
# 0  5.590650
# 1  5.466122
# 2  6.088268
# 3  6.793538
# 4  5.970548

# %%
y_predict=y_predict.apply(lambda k:round(k))
y_predict.head()
# Out:
#      0
# 0  6.0
# 1  5.0
# 2  6.0
# 3  7.0
# 4  6.0

# %%
mse = mean_squared_error(Y_test,y_predict)#,multioutput='uniform_average')

# %%
mse
# Out:
# 0.75816326530612244

# %%
rmse = math.sqrt(mse)

# %%
rmse
# Out:
# 0.8707257118669015

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
#visualizer = ResidualsPlot(regr)

#visualizer.fit(X_train, Y_train)  # Fit the training data to the visualizer
#visualizer.score(X_test, Y_test)  # Evaluate the model on the test data
#g = visualizer.poof()             # Draw/show/poof the data
